# %%
import requests
import dlt
from dlt.sources.helpers import requests
import os
from dotenv import load_dotenv
import duckdb
import html2text
import re 
from boilerpy3 import extractors
from bs4 import BeautifulSoup

load_dotenv(override=True)

def get_stackexchange_data(tag=None,site='philosophy',page=1,pagesize=100):
  """Fetches data from the Stack Exchange API.
  
  Args:
    tag: The tag to search for.
    site: The Stack Exchange site (default: 'stackoverflow').
    page: The page number.
    pagesize: The number of items per page (max 100).

  Returns:
    A dictionary containing the API response.
  """

  url = "https://api.stackexchange.com/2.3/questions"
  # API to get the answers for a certain question with question id
  # https://api.stackexchange.com/2.3/questions/108037/answers?site=stackoverflow&filter=withbody
  params = {
    "site": site,
    "order": "asc",
    "sort": "creation",
    # "tagged": tag,
    "page": page,
    "pagesize": pagesize,
    "key": os.getenv("SE_API_KEY"),
    "filter": "withbody"
    
  }
  response = requests.get(url,params=params)
  return response.json()

# data = get_stackexchange_data()
# print(data)

# %% [markdown]
# # Data Ingestion

# %%
@dlt.resource(table_name="philosophy_questions", write_disposition="append")
def get_questions(
    tag=None, 
    site='philosophy',
    page=1,
    pagesize=100
):
    
    url = "https://api.stackexchange.com/2.3/questions"
    params = {
        "site": site,
        "order": "asc",
        "sort": "creation",
        # "tagged": tag,
        "page": page,
        "pagesize": pagesize,
        "key": os.getenv("SE_API_KEY"),
        "filter": "withbody"        
    }

    while True:
        response = requests.get(url,params=params)
        response.raise_for_status()
        yield response.json()

        if response.json()["has_more"]==False:
            break

        if params["page"]==300:
            break
        
        params["page"]+=1

# %%
pipeline = dlt.pipeline(
    pipeline_name="philosophy_questions_incremental",
    destination="duckdb",
    dataset_name="philosophy_questions",
)

# load_info = pipeline.run(get_questions())
# row_counts = pipeline.last_trace.last_normalize_info

# print(row_counts)
# print("------")
# print(load_info)

# %%
conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

conn.sql(f"SET search_path = '{pipeline.dataset_name}'")
print('Loaded tables: ')
display(conn.sql("show tables"))
# Out:
# Loaded tables:
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │                                    name                                     │
# │                                   varchar                                   │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │ _dlt_loads                                                                  │
# │ _dlt_pipeline_state                                                         │
# │ _dlt_version                                                                │
# │ philosophy_questions                                                        │
# │ philosophy_questions__items                                                 │
# │ philosophy_questions__items__migrated_from__other_site__aliases             │
# │ philosophy_questions__items__migrated_from__other_site__markdown_extensions │
# │ philosophy_questions__items__migrated_from__other_site__related_sites       │
# │ philosophy_questions__items__tags                                           │
# └─────────────────────────────────────────────────────────────────────────────┘

# %%
questions = conn.sql("SELECT * FROM philosophy_questions__items").df()
display(questions)
# Out:
#        owner__account_id  owner__reputation  owner__user_id owner__user_type  \
# 0             16491829.0            18695.0         40843.0       registered
# 1             29736116.0             2914.0         68482.0       registered
# 2              5253885.0              335.0         47770.0       registered
# 3                    NaN                NaN             NaN   does_not_exist
# 4             19780752.0             1507.0         77058.0       registered
# ...                  ...                ...             ...              ...
# 22743            59775.0             2067.0            72.0       registered
# 22744            32433.0             9670.0            81.0        moderator
# 22745           157369.0              887.0            13.0       registered
# 22746            14250.0              375.0           102.0       registered
# 22747            14250.0              375.0           102.0       registered
#
#                                     owner__profile_image owner__display_name  \
# 0      https://graph.facebook.com/10157462114367910/p...      Kristian Berry
# 1                  https://i.sstatic.net/yOM8W.jpg?s=256             Meanach
# 2      https://www.gravatar.com/avatar/c2570aa785c372...                user
# 3                                                   None           user62907
# 4      https://www.gravatar.com/avatar/dce3e1a595d736...           user77058
# ...                                                  ...                 ...
# 22743  https://www.gravatar.com/avatar/487b39e86dd577...                 Jez
# 22744  https://www.gravatar.com/avatar/c4752b73a675b7...     Joseph Weissman
# 22745              https://i.sstatic.net/LY3kx.jpg?s=256                 mfg
# 22746  https://www.gravatar.com/avatar/deee1379ed13c9...         DuckMaestro
# 22747  https://www.gravatar.com/avatar/deee1379ed13c9...         DuckMaestro
#
#                                              owner__link  is_answered  \
# 0      https://philosophy.stackexchange.com/users/408...         True
# 1      https://philosophy.stackexchange.com/users/684...         True
# 2      https://philosophy.stackexchange.com/users/477...        False
# 3                                                   None         True
# 4      https://philosophy.stackexchange.com/users/770...         True
# ...                                                  ...          ...
# 22743  https://philosophy.stackexchange.com/users/72/jez         True
# 22744  https://philosophy.stackexchange.com/users/81/...         True
# 22745  https://philosophy.stackexchange.com/users/13/mfg         True
# 22746  https://philosophy.stackexchange.com/users/102...         True
# 22747  https://philosophy.stackexchange.com/users/102...         True
#
#        view_count  answer_count  ...  migrated_from__other_site__icon_url  \
# 0              23             1  ...                                 None
# 1             103             4  ...                                 None
# 2             149             2  ...                                 None
# 3             344             8  ...                                 None
# 4             210             1  ...                                 None
# ...           ...           ...  ...                                  ...
# 22743        3315             1  ...                                 None
# 22744        3255             2  ...                                 None
# 22745       10332             1  ...                                 None
# 22746        1158             1  ...                                 None
# 22747        1143             1  ...                                 None
#
#        migrated_from__other_site__audience  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# ...                                    ...
# 22743                                 None
# 22744                                 None
# 22745                                 None
# 22746                                 None
# 22747                                 None
#
#        migrated_from__other_site__site_url  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# ...                                    ...
# 22743                                 None
# 22744                                 None
# 22745                                 None
# 22746                                 None
# 22747                                 None
#
#        migrated_from__other_site__api_site_parameter  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# ...                                              ...
# 22743                                           None
# 22744                                           None
# 22745                                           None
# 22746                                           None
# 22747                                           None
#
#        migrated_from__other_site__logo_url migrated_from__other_site__name  \
# 0                                     None                            None
# 1                                     None                            None
# 2                                     None                            None
# 3                                     None                            None
# 4                                     None                            None
# ...                                    ...                             ...
# 22743                                 None                            None
# 22744                                 None                            None
# 22745                                 None                            None
# 22746                                 None                            None
# 22747                                 None                            None
#
#       migrated_from__other_site__site_type migrated_from__on_date  \
# 0                                     None                    NaN
# 1                                     None                    NaN
# 2                                     None                    NaN
# 3                                     None                    NaN
# 4                                     None                    NaN
# ...                                    ...                    ...
# 22743                                 None                    NaN
# 22744                                 None                    NaN
# 22745                                 None                    NaN
# 22746                                 None                    NaN
# 22747                                 None                    NaN
#
#       migrated_from__question_id community_owned_date
# 0                            NaN                  NaN
# 1                            NaN                  NaN
# 2                            NaN                  NaN
# 3                            NaN                  NaN
# 4                            NaN                  NaN
# ...                          ...                  ...
# 22743                        NaN                  NaN
# 22744                        NaN                  NaN
# 22745                        NaN                  NaN
# 22746                        NaN                  NaN
# 22747                        NaN                  NaN
#
# [22748 rows x 47 columns]

# %%
questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22748 entries, 0 to 22747
# Data columns (total 47 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   owner__account_id                                         20153 non-null  float64
#  1   owner__reputation                                         20153 non-null  float64
#  2   owner__user_id                                            20153 non-null  float64
#  3   owner__user_type                                          22748 non-null  object
#  4   owner__profile_image                                      20153 non-null  object
#  5   owner__display_name                                       22748 non-null  object
#  6   owner__link                                               20153 non-null  object
#  7   is_answered                                               22748 non-null  bool
#  8   view_count                                                22748 non-null  int64
#  9   answer_count                                              22748 non-null  int64
#  10  score                                                     22748 non-null  int64
#  11  last_activity_date                                        22748 non-null  int64
#  12  creation_date                                             22748 non-null  int64
#  13  last_edit_date                                            13660 non-null  float64
#  14  question_id                                               22748 non-null  int64
#  15  content_license                                           19891 non-null  object
#  16  link                                                      22748 non-null  object
#  17  title                                                     22748 non-null  object
#  18  body                                                      22748 non-null  object
#  19  _dlt_parent_id                                            22748 non-null  object
#  20  _dlt_list_idx                                             22748 non-null  int64
#  21  _dlt_id                                                   22748 non-null  object
#  22  closed_date                                               2777 non-null   float64
#  23  closed_reason                                             2777 non-null   object
#  24  owner__accept_rate                                        4647 non-null   float64
#  25  accepted_answer_id                                        7587 non-null   float64
#  26  locked_date                                               17 non-null     float64
#  27  protected_date                                            292 non-null    float64
#  28  migrated_from__other_site__styling__tag_background_color  86 non-null     object
#  29  migrated_from__other_site__styling__tag_foreground_color  86 non-null     object
#  30  migrated_from__other_site__styling__link_color            86 non-null     object
#  31  migrated_from__other_site__launch_date                    85 non-null     float64
#  32  migrated_from__other_site__open_beta_date                 85 non-null     float64
#  33  migrated_from__other_site__closed_beta_date               85 non-null     float64
#  34  migrated_from__other_site__site_state                     86 non-null     object
#  35  migrated_from__other_site__high_resolution_icon_url       86 non-null     object
#  36  migrated_from__other_site__favicon_url                    86 non-null     object
#  37  migrated_from__other_site__icon_url                       86 non-null     object
#  38  migrated_from__other_site__audience                       86 non-null     object
#  39  migrated_from__other_site__site_url                       86 non-null     object
#  40  migrated_from__other_site__api_site_parameter             86 non-null     object
#  41  migrated_from__other_site__logo_url                       86 non-null     object
#  42  migrated_from__other_site__name                           86 non-null     object
#  43  migrated_from__other_site__site_type                      86 non-null     object
#  44  migrated_from__on_date                                    86 non-null     float64
#  45  migrated_from__question_id                                86 non-null     float64
#  46  community_owned_date                                      13 non-null     float64
# dtypes: bool(1), float64(15), int64(7), object(24)
# memory usage: 8.0+ MB

# %%
# CREATE A NEW TABLE WITH THE RowNum TO COUNT DUPLICATE
# conn.sql(
#     """
#     CREATE TABLE stackoverflow_questions_items_with_duplicates_count AS (
#     SELECT *, ROW_NUMBER() OVER (PARTITION BY body ORDER BY creation_date) AS RowNum
#     FROM stackoverflow_questions__items 
#     ) 
#     """
# )

# DELETE THE DUPLICATE ENTRIES FROM THE TABLE
# conn.sql(
#     """
#     DELETE FROM stackoverflow_questions_items_with_duplicates_count
#     WHERE RowNum > 1
#     """
# )

# %% [markdown]
# ##### Get the Data for Answered Questions

# %%
answered_questions = questions[questions["is_answered"]==True]

# %%
answered_questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19285 entries, 0 to 22747
# Data columns (total 47 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   owner__account_id                                         17080 non-null  float64
#  1   owner__reputation                                         17080 non-null  float64
#  2   owner__user_id                                            17080 non-null  float64
#  3   owner__user_type                                          19285 non-null  object
#  4   owner__profile_image                                      17080 non-null  object
#  5   owner__display_name                                       19285 non-null  object
#  6   owner__link                                               17080 non-null  object
#  7   is_answered                                               19285 non-null  bool
#  8   view_count                                                19285 non-null  int64
#  9   answer_count                                              19285 non-null  int64
#  10  score                                                     19285 non-null  int64
#  11  last_activity_date                                        19285 non-null  int64
#  12  creation_date                                             19285 non-null  int64
#  13  last_edit_date                                            12094 non-null  float64
#  14  question_id                                               19285 non-null  int64
#  15  content_license                                           16899 non-null  object
#  16  link                                                      19285 non-null  object
#  17  title                                                     19285 non-null  object
#  18  body                                                      19285 non-null  object
#  19  _dlt_parent_id                                            19285 non-null  object
#  20  _dlt_list_idx                                             19285 non-null  int64
#  21  _dlt_id                                                   19285 non-null  object
#  22  closed_date                                               2308 non-null   float64
#  23  closed_reason                                             2308 non-null   object
#  24  owner__accept_rate                                        4255 non-null   float64
#  25  accepted_answer_id                                        7587 non-null   float64
#  26  locked_date                                               15 non-null     float64
#  27  protected_date                                            290 non-null    float64
#  28  migrated_from__other_site__styling__tag_background_color  83 non-null     object
#  29  migrated_from__other_site__styling__tag_foreground_color  83 non-null     object
#  30  migrated_from__other_site__styling__link_color            83 non-null     object
#  31  migrated_from__other_site__launch_date                    82 non-null     float64
#  32  migrated_from__other_site__open_beta_date                 82 non-null     float64
#  33  migrated_from__other_site__closed_beta_date               82 non-null     float64
#  34  migrated_from__other_site__site_state                     83 non-null     object
#  35  migrated_from__other_site__high_resolution_icon_url       83 non-null     object
#  36  migrated_from__other_site__favicon_url                    83 non-null     object
#  37  migrated_from__other_site__icon_url                       83 non-null     object
#  38  migrated_from__other_site__audience                       83 non-null     object
#  39  migrated_from__other_site__site_url                       83 non-null     object
#  40  migrated_from__other_site__api_site_parameter             83 non-null     object
#  41  migrated_from__other_site__logo_url                       83 non-null     object
#  42  migrated_from__other_site__name                           83 non-null     object
#  43  migrated_from__other_site__site_type                      83 non-null     object
#  44  migrated_from__on_date                                    83 non-null     float64
#  45  migrated_from__question_id                                83 non-null     float64
#  46  community_owned_date                                      13 non-null     float64
# dtypes: bool(1), float64(15), int64(7), object(24)
# memory usage: 6.9+ MB

# %%
answered_questions.head()
# Out:
#    owner__account_id  owner__reputation  owner__user_id owner__user_type  \
# 0         16491829.0            18695.0         40843.0       registered
# 1         29736116.0             2914.0         68482.0       registered
# 3                NaN                NaN             NaN   does_not_exist
# 4         19780752.0             1507.0         77058.0       registered
# 6         17436487.0              111.0         43600.0       registered
#
#                                 owner__profile_image owner__display_name  \
# 0  https://graph.facebook.com/10157462114367910/p...      Kristian Berry
# 1              https://i.sstatic.net/yOM8W.jpg?s=256             Meanach
# 3                                               None           user62907
# 4  https://www.gravatar.com/avatar/dce3e1a595d736...           user77058
# 6  https://graph.facebook.com/117598566407271/pic...          Zhang Hong
#
#                                          owner__link  is_answered  view_count  \
# 0  https://philosophy.stackexchange.com/users/408...         True          23
# 1  https://philosophy.stackexchange.com/users/684...         True         103
# 3                                               None         True         344
# 4  https://philosophy.stackexchange.com/users/770...         True         210
# 6  https://philosophy.stackexchange.com/users/436...         True        4754
#
#    answer_count  ...  migrated_from__other_site__icon_url  \
# 0             1  ...                                 None
# 1             4  ...                                 None
# 3             8  ...                                 None
# 4             1  ...                                 None
# 6             8  ...                                 None
#
#    migrated_from__other_site__audience  migrated_from__other_site__site_url  \
# 0                                 None                                 None
# 1                                 None                                 None
# 3                                 None                                 None
# 4                                 None                                 None
# 6                                 None                                 None
#
#    migrated_from__other_site__api_site_parameter  \
# 0                                           None
# 1                                           None
# 3                                           None
# 4                                           None
# 6                                           None
#
#    migrated_from__other_site__logo_url migrated_from__other_site__name  \
# 0                                 None                            None
# 1                                 None                            None
# 3                                 None                            None
# 4                                 None                            None
# 6                                 None                            None
#
#   migrated_from__other_site__site_type migrated_from__on_date  \
# 0                                 None                    NaN
# 1                                 None                    NaN
# 3                                 None                    NaN
# 4                                 None                    NaN
# 6                                 None                    NaN
#
#   migrated_from__question_id community_owned_date
# 0                        NaN                  NaN
# 1                        NaN                  NaN
# 3                        NaN                  NaN
# 4                        NaN                  NaN
# 6                        NaN                  NaN
#
# [5 rows x 47 columns]

# %% [markdown]
# ##### Check for Duplicate Entries

# %%
answered_questions.duplicated().sum()
# Out:
# 0

# %%
answered_questions = answered_questions.iloc[:2000]

# %%
@dlt.resource(table_name="philosophy_answers", write_disposition="append")
def get_answers(
    tag=None, 
    site='philosophy',
    page=1,
    pagesize=100,
    questions_id=list(answered_questions["question_id"])
):
    
    for i in range(len(questions_id)):
        url = "https://api.stackexchange.com/2.3/questions" + f"/{questions_id[i]}" + "/answers" 
        params = {
            "site": site,
            # "tagged": tag,
            "page": page,
            "pagesize": pagesize,
            "key": os.getenv("SE_API_KEY"),
            "filter": "withbody"        
        }

        while True:
            response = requests.get(url,params=params)
            response.raise_for_status()
            yield response.json()

            if response.json()["has_more"]==False:
                break
            
            params["page"]+=1

# %%
pipeline = dlt.pipeline(
    pipeline_name="philosophy_answers_incremental",
    destination="duckdb",
    dataset_name="philosophy_answers",
)

# load_info = pipeline.run(get_answers())
# row_counts = pipeline.last_trace.last_normalize_info

# print(row_counts)
# print("------")
# print(load_info)

# %%
conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

conn.sql(f"SET search_path = '{pipeline.dataset_name}'")
print('Loaded tables: ')
display(conn.sql("show tables"))
# Out:
# Loaded tables:
# ┌───────────────────────────┐
# │           name            │
# │          varchar          │
# ├───────────────────────────┤
# │ _dlt_loads                │
# │ _dlt_pipeline_state       │
# │ _dlt_version              │
# │ philosophy_answers        │
# │ philosophy_answers__items │
# └───────────────────────────┘

# %%
answers = conn.sql("SELECT * FROM philosophy_answers__items").df()
display(answers)
# Out:
#       owner__account_id  owner__reputation  owner__user_id owner__user_type  \
# 0            16252558.0            31306.0         40730.0       registered
# 1             4556922.0             4291.0         37256.0       registered
# 2            29116279.0             2450.0         67046.0       registered
# 3            29736116.0             2914.0         68482.0       registered
# 4             4896115.0            36748.0          9174.0       registered
# ...                 ...                ...             ...              ...
# 8192         12482509.0            11027.0         50852.0       registered
# 8193          4896115.0            36748.0          9174.0       registered
# 8194         12141261.0            15091.0         29339.0       registered
# 8195         29736116.0             2914.0         68482.0       registered
# 8196         29786117.0             2798.0         68612.0       registered
#
#                                    owner__profile_image owner__display_name  \
# 0     https://www.gravatar.com/avatar/b4e30985026dd7...                 J D
# 1     https://www.gravatar.com/avatar/cad58aa1de61af...               Rushi
# 2     https://www.gravatar.com/avatar/d7e7397a342ef4...            Olivier5
# 3                 https://i.sstatic.net/yOM8W.jpg?s=256             Meanach
# 4                 https://i.sstatic.net/ddQui.jpg?s=256           Jo Wehler
# ...                                                 ...                 ...
# 8192  https://www.gravatar.com/avatar/488ae937ea41c0...       David Gudeman
# 8193              https://i.sstatic.net/ddQui.jpg?s=256           Jo Wehler
# 8194              https://i.sstatic.net/0VofS.jpg?s=256              Dcleve
# 8195              https://i.sstatic.net/yOM8W.jpg?s=256             Meanach
# 8196  https://lh3.googleusercontent.com/a/ACg8ocLc2z...      Ioannis Paizis
#
#                                             owner__link  is_accepted  score  \
# 0     https://philosophy.stackexchange.com/users/407...        False      3
# 1     https://philosophy.stackexchange.com/users/372...        False      1
# 2     https://philosophy.stackexchange.com/users/670...        False      2
# 3     https://philosophy.stackexchange.com/users/684...        False      2
# 4     https://philosophy.stackexchange.com/users/917...        False      1
# ...                                                 ...          ...    ...
# 8192  https://philosophy.stackexchange.com/users/508...        False      3
# 8193  https://philosophy.stackexchange.com/users/917...        False      1
# 8194  https://philosophy.stackexchange.com/users/293...        False      0
# 8195  https://philosophy.stackexchange.com/users/684...        False      0
# 8196  https://philosophy.stackexchange.com/users/686...        False     -3
#
#       last_activity_date  ...  answer_id  question_id  content_license  \
# 0             1725632358  ...     116886       116884     CC BY-SA 4.0
# 1             1725631539  ...     116881       116834     CC BY-SA 4.0
# 2             1725624713  ...     116882       116834     CC BY-SA 4.0
# 3             1725610565  ...     116878       116834     CC BY-SA 4.0
# 4             1725464830  ...     116839       116834     CC BY-SA 4.0
# ...                  ...  ...        ...          ...              ...
# 8192          1683860487  ...      99227        99225     CC BY-SA 4.0
# 8193          1703321679  ...     106655       106274     CC BY-SA 4.0
# 8194          1702837558  ...     106488       106274     CC BY-SA 4.0
# 8195          1702836041  ...     106485       106274     CC BY-SA 4.0
# 8196          1702469815  ...     106325       106274     CC BY-SA 4.0
#
#                                                    body  _dlt_parent_id  \
# 0     <p><em>You used a question mark as a superscri...  wnCoJ+8xcSGfAg
# 1     <p>There have been a number of philosophers of...  2/+CVrJnVEuYfg
# 2     <p>Lots of great answers and suggestions. Let ...  2/+CVrJnVEuYfg
# 3     <p>I paraphrase Churchill, but this version co...  2/+CVrJnVEuYfg
# 4     <ol>\n<li><p>Your question starts with a presu...  2/+CVrJnVEuYfg
# ...                                                 ...             ...
# 8192  <p>The clue is in the fact that he called it <...  69f5IZd441aYLw
# 8193  <p>Following the suggestion of @MauroALLEGRANZ...  opfDfei1nTH+iQ
# 8194  <p>The core problem that you are asking about,...  opfDfei1nTH+iQ
# 8195  <p>I am afraid that your question describes a ...  opfDfei1nTH+iQ
# 8196  <p>These two aspects you are talking about are...  opfDfei1nTH+iQ
#
#      _dlt_list_idx         _dlt_id last_edit_date  owner__accept_rate  \
# 0                0  4ZfPEQTz3J4Q+A            NaN                 NaN
# 1                0  OcVSPXuYlR7/qg   1.725632e+09                 NaN
# 2                1  I3/Pz9DCXCqrhA            NaN                 NaN
# 3                2  khn6NuV1YSHUKQ            NaN                 NaN
# 4                3  NY1XJjqF0b+W8w            NaN                62.0
# ...            ...             ...            ...                 ...
# 8192             2  4b5rjXngZt/o7g            NaN                 NaN
# 8193             0  +LPgvTAcfPWL1A   1.703322e+09                62.0
# 8194             1  JnQ0FbklNgIruQ            NaN                 NaN
# 8195             2  fIqkGTSNe70vxw            NaN                 NaN
# 8196             3  nHvW30KfjvB3ag   1.702470e+09                 NaN
#
#       community_owned_date
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 8192                   NaN
# 8193                   NaN
# 8194                   NaN
# 8195                   NaN
# 8196                   NaN
#
# [8197 rows x 21 columns]

# %%
answers["body"].iloc[0]
# Out:
# '<p><em>You used a question mark as a superscript to a question mark. Awesome. :D</em></p>\n<p>You say:</p>\n<blockquote>\n<p>So wouldn\'t a quantifier-free language have to eschew set theory and arithmetic to that extent, to get to where its speakers would want to go? Might that destabilize such a language even more, then, though?</p>\n</blockquote>\n<p>So, let\'s draw a very clear line in the sand. One can talk about natural languages which are a product of evolution and shared intentionality (according to Tomasello at least), or one can talk about artificial languages like those developed by Descartes, Frege, and the modern mathematical logician or programming grammar engineer. <strong>Understanding how natural languages can be more fully understood with formalisms is the central focus of linguistic formal semantics, a movement started by <a href="https://en.wikipedia.org/wiki/Richard_Montague" rel="nofollow noreferrer">Richard Monatague</a> and championed by <a href="https://en.wikipedia.org/wiki/Barbara_H._Partee" rel="nofollow noreferrer">Barbara Partee</a>, among others.</strong> A good introduction from Cambridge Press is <a href="https://www.google.com/books/edition/Formal_Semantics/MMBk252R-6QC?hl=en&amp;gbpv=0" rel="nofollow noreferrer">Cann\'s <em>Formal Semantics: An Introduction</em></a>.</p>\n<p><strong>The article on Generalized Quantifiers (SEP) says &quot;[i]n the late 1960\'s, Richard Montague showed how the semantics of significant parts of natural languages could be handled with logical tools.&quot;</strong> This was a part of a broader movement in linguistics that shifted the Bloomfieldian descriptive methodology which an emphasis on phonology towards semantics through syntax, starting with Chomsky\'s <em>Structures</em> and then <em>Aspects</em>. By the late 1960\'s, it was fully apparent to many that the meaning described by logical languages lined up neatly with Chomsky\'s Transformational Grammar as a failed movement called <a href="https://en.wikipedia.org/wiki/Generative_semantics" rel="nofollow noreferrer">generative semantics</a> divided the linguists at MIT and elsewhere.</p>\n<p>Now, when you talk of quanitifier free languages like Quine\'s <a href="https://en.wikipedia.org/wiki/Predicate_functor_logic" rel="nofollow noreferrer">predicate functor logic</a>, you are referring to an artificial languages which intentionally eschews explicit quantification. As far as I know, <strong>no natural language is entirely free of quantifier expressions to express ontological commitment, and even if one exists, noun phrases with nouns and modifiers would function implicitly to express <a href="https://en.wikipedia.org/wiki/Ontological_commitment" rel="nofollow noreferrer">ontological commitment</a>.</strong> From the SEP article on generalized quantifiers:</p>\n<blockquote>\n<p>One of his main insights was that noun phrases... can be interpreted as sets of subsets of the domain... Montague worked in type theory, but around 1980 a number of linguists and logicians began to apply the model-theoretic framework of logics with generalized quantifiers to natural language semantics.</p>\n</blockquote>\n<p>And combined with Hirsch\'s work on <a href="https://en.wikipedia.org/wiki/Quantifier_variance" rel="nofollow noreferrer">quantifier variance</a> which stems from Urmson\'s dictum, <strong>Quine\'s notion of ontological relativity has been advanced to the point that <a href="https://plato.stanford.edu/entries/natural-language-ontology/" rel="nofollow noreferrer">natural language ontology (SEP)</a> can be implemented rather well on an arbitrary natural language through the use of formal tools, such as <a href="https://en.wikipedia.org/wiki/Grammatical_Framework_(programming_language)" rel="nofollow noreferrer">Arne Ranta\'s Grammatical Framework</a></strong>. Currently, the grammar grammar describers close to 20 natural languages and is used as a substitute for conventional NLP strategies that are stochastic.</p>\n ...
