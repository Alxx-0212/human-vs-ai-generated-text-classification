# %%
import dlt
from dlt.sources.helpers import requests
import os
from dotenv import load_dotenv
import datetime
import duckdb
from preprocess_raw_html import preprocess_raw_html # created function
from openai import AzureOpenAI
import time
import pandas as pd
import jsonlines
import json
import re
import matplotlib.pyplot as plt
from matplotlib_venn import venn3,venn2,venn2_circles
import pyarrow as pa
import pyarrow.parquet as pq

load_dotenv(override=True)
pd.set_option('display.max_columns', None) 
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Get the Philosophy Questions Stored in DuckDB

# %%
pipeline = dlt.pipeline(
    pipeline_name="philosophy_questions_incremental",
    destination="duckdb",
    dataset_name="philosophy_questions",
)

conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

conn.sql(f"SET search_path = '{pipeline.dataset_name}'")
print('Loaded tables: ')
display(conn.sql("show tables"))
# Out:
# Loaded tables:
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │                                    name                                     │
# │                                   varchar                                   │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │ _dlt_loads                                                                  │
# │ _dlt_pipeline_state                                                         │
# │ _dlt_version                                                                │
# │ philosophy_questions                                                        │
# │ philosophy_questions__items                                                 │
# │ philosophy_questions__items__migrated_from__other_site__aliases             │
# │ philosophy_questions__items__migrated_from__other_site__markdown_extensions │
# │ philosophy_questions__items__migrated_from__other_site__related_sites       │
# │ philosophy_questions__items__tags                                           │
# └─────────────────────────────────────────────────────────────────────────────┘

# %%
questions = conn.sql("SELECT * FROM philosophy_questions__items").df()
questions.head()
# Out:
#    owner__account_id  owner__reputation  owner__user_id owner__user_type  \
# 0         16491829.0            18695.0         40843.0       registered
# 1         29736116.0             2914.0         68482.0       registered
# 2          5253885.0              335.0         47770.0       registered
# 3                NaN                NaN             NaN   does_not_exist
# 4         19780752.0             1507.0         77058.0       registered
#
#                                 owner__profile_image owner__display_name  \
# 0  https://graph.facebook.com/10157462114367910/p...      Kristian Berry
# 1              https://i.sstatic.net/yOM8W.jpg?s=256             Meanach
# 2  https://www.gravatar.com/avatar/c2570aa785c372...                user
# 3                                               None           user62907
# 4  https://www.gravatar.com/avatar/dce3e1a595d736...           user77058
#
#                                          owner__link  is_answered  view_count  \
# 0  https://philosophy.stackexchange.com/users/408...         True          23
# 1  https://philosophy.stackexchange.com/users/684...         True         103
# 2  https://philosophy.stackexchange.com/users/477...        False         149
# 3                                               None         True         344
# 4  https://philosophy.stackexchange.com/users/770...         True         210
#
#    answer_count  score  last_activity_date  creation_date  last_edit_date  \
# 0             1      0          1725632518     1725626518    1.725633e+09
# 1             4      1          1725631539     1725462078             NaN
# 2             2      1          1725629098     1693675067    1.700492e+09
# 3             8      3          1725626506     1665130403    1.725524e+09
# 4             1      0          1725619849     1725455271    1.725620e+09
#
#    question_id content_license  \
# 0       116884    CC BY-SA 4.0
# 1       116834    CC BY-SA 4.0
# 2       102488    CC BY-SA 4.0
# 3        94063    CC BY-SA 4.0
# 4       116828            None
#
#                                                 link  \
# 0  https://philosophy.stackexchange.com/questions...
# 1  https://philosophy.stackexchange.com/questions...
# 2  https://philosophy.stackexchange.com/questions...
# 3  https://philosophy.stackexchange.com/questions...
# 4  https://philosophy.stackexchange.com/questions...
#
#                                                title  \
# 0  Is a stable quantifier-free language really po...
# 1  Churchill said that democracy is the worst for...
# 2  If someone lacks the will to live, can there s...
# 3  Can we assign probabilities to God and is the ...
# 4  Can the strength of evidence for a proposition...
#
#                                                 body  _dlt_parent_id  \
# 0  <p>I'm reading the yesterday-updated SEP entry...  zcTBbU9rMWMC0Q
# 1  <p>I was intrigued by a recent question about ...  zcTBbU9rMWMC0Q
# 2  <p>After reading some posts such as <a href="h...  zcTBbU9rMWMC0Q
# 3  <p>Dawkins essentially argues that if one obse...  zcTBbU9rMWMC0Q
# 4  <p>Questions such as <a href="https://philosop...  zcTBbU9rMWMC0Q
#
#    _dlt_list_idx         _dlt_id   closed_date closed_reason  \
# 0              0  MsT4h//bUH+5vQ           NaN          None
# 1              1  rrvOKbIJX0vckA           NaN          None
# 2              2  B1GJvYnou9fkZA           NaN          None
# 3              3  HUL5WSXsdzaGkQ           NaN          None
# 4              4  Tn6khuidGV1ezw  1.725523e+09     Duplicate
#
#    owner__accept_rate  accepted_answer_id  locked_date  protected_date  \
# 0                 NaN                 NaN          NaN             NaN
# 1                 NaN                 NaN          NaN             NaN
# 2                 NaN                 NaN          NaN             NaN
# 3                 NaN                 NaN          NaN             NaN
# 4                 NaN                 NaN          NaN             NaN
#
#   migrated_from__other_site__styling__tag_background_color  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   migrated_from__other_site__styling__tag_foreground_color  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   migrated_from__other_site__styling__link_color  \
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
#
#    migrated_from__other_site__launch_date  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    migrated_from__other_site__open_beta_date  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    migrated_from__other_site__closed_beta_date  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   migrated_from__other_site__site_state  \
# 0                                  None
# 1                                  None
# 2                                  None
# 3                                  None
# 4                                  None
#
#   migrated_from__other_site__high_resolution_icon_url  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   migrated_from__other_site__favicon_url migrated_from__other_site__icon_url  \
# 0                                   None                                None
# 1                                   None                                None
# 2                                   None                                None
# 3                                   None                                None
# 4                                   None                                None
#
#   migrated_from__other_site__audience migrated_from__other_site__site_url  \
# 0                                None                                None
# 1                                None                                None
# 2                                None                                None
# 3                                None                                None
# 4                                None                                None
#
#   migrated_from__other_site__api_site_parameter  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
#
#   migrated_from__other_site__logo_url migrated_from__other_site__name  \
# 0                                None                            None
# 1                                None                            None
# 2                                None                            None
# 3                                None                            None
# 4                                None                            None
#
#   migrated_from__other_site__site_type  migrated_from__on_date  \
# 0                                 None                     NaN
# 1                                 None                     NaN
# 2                                 None                     NaN
# 3                                 None                     NaN
# 4                                 None                     NaN
#
#    migrated_from__question_id  community_owned_date
# 0                         NaN                   NaN
# 1                         NaN                   NaN
# 2                         NaN                   NaN
# 3                         NaN                   NaN
# 4                         NaN                   NaN

# %%
questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22748 entries, 0 to 22747
# Data columns (total 47 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   owner__account_id                                         20153 non-null  float64
#  1   owner__reputation                                         20153 non-null  float64
#  2   owner__user_id                                            20153 non-null  float64
#  3   owner__user_type                                          22748 non-null  object
#  4   owner__profile_image                                      20153 non-null  object
#  5   owner__display_name                                       22748 non-null  object
#  6   owner__link                                               20153 non-null  object
#  7   is_answered                                               22748 non-null  bool
#  8   view_count                                                22748 non-null  int64
#  9   answer_count                                              22748 non-null  int64
#  10  score                                                     22748 non-null  int64
#  11  last_activity_date                                        22748 non-null  int64
#  12  creation_date                                             22748 non-null  int64
#  13  last_edit_date                                            13660 non-null  float64
#  14  question_id                                               22748 non-null  int64
#  15  content_license                                           19891 non-null  object
#  16  link                                                      22748 non-null  object
#  17  title                                                     22748 non-null  object
#  18  body                                                      22748 non-null  object
#  19  _dlt_parent_id                                            22748 non-null  object
#  20  _dlt_list_idx                                             22748 non-null  int64
#  21  _dlt_id                                                   22748 non-null  object
#  22  closed_date                                               2777 non-null   float64
#  23  closed_reason                                             2777 non-null   object
#  24  owner__accept_rate                                        4647 non-null   float64
#  25  accepted_answer_id                                        7587 non-null   float64
#  26  locked_date                                               17 non-null     float64
#  27  protected_date                                            292 non-null    float64
#  28  migrated_from__other_site__styling__tag_background_color  86 non-null     object
#  29  migrated_from__other_site__styling__tag_foreground_color  86 non-null     object
#  30  migrated_from__other_site__styling__link_color            86 non-null     object
#  31  migrated_from__other_site__launch_date                    85 non-null     float64
#  32  migrated_from__other_site__open_beta_date                 85 non-null     float64
#  33  migrated_from__other_site__closed_beta_date               85 non-null     float64
#  34  migrated_from__other_site__site_state                     86 non-null     object
#  35  migrated_from__other_site__high_resolution_icon_url       86 non-null     object
#  36  migrated_from__other_site__favicon_url                    86 non-null     object
#  37  migrated_from__other_site__icon_url                       86 non-null     object
#  38  migrated_from__other_site__audience                       86 non-null     object
#  39  migrated_from__other_site__site_url                       86 non-null     object
#  40  migrated_from__other_site__api_site_parameter             86 non-null     object
#  41  migrated_from__other_site__logo_url                       86 non-null     object
#  42  migrated_from__other_site__name                           86 non-null     object
#  43  migrated_from__other_site__site_type                      86 non-null     object
#  44  migrated_from__on_date                                    86 non-null     float64
#  45  migrated_from__question_id                                86 non-null     float64
#  46  community_owned_date                                      13 non-null     float64
# dtypes: bool(1), float64(15), int64(7), object(24)
# memory usage: 8.0+ MB

# %% [markdown]
# ##### Answered Philosophy Questions

# %%
answered_questions = questions[questions["is_answered"]==True]

# %%
answered_questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19285 entries, 0 to 22747
# Data columns (total 47 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   owner__account_id                                         17080 non-null  float64
#  1   owner__reputation                                         17080 non-null  float64
#  2   owner__user_id                                            17080 non-null  float64
#  3   owner__user_type                                          19285 non-null  object
#  4   owner__profile_image                                      17080 non-null  object
#  5   owner__display_name                                       19285 non-null  object
#  6   owner__link                                               17080 non-null  object
#  7   is_answered                                               19285 non-null  bool
#  8   view_count                                                19285 non-null  int64
#  9   answer_count                                              19285 non-null  int64
#  10  score                                                     19285 non-null  int64
#  11  last_activity_date                                        19285 non-null  int64
#  12  creation_date                                             19285 non-null  int64
#  13  last_edit_date                                            12094 non-null  float64
#  14  question_id                                               19285 non-null  int64
#  15  content_license                                           16899 non-null  object
#  16  link                                                      19285 non-null  object
#  17  title                                                     19285 non-null  object
#  18  body                                                      19285 non-null  object
#  19  _dlt_parent_id                                            19285 non-null  object
#  20  _dlt_list_idx                                             19285 non-null  int64
#  21  _dlt_id                                                   19285 non-null  object
#  22  closed_date                                               2308 non-null   float64
#  23  closed_reason                                             2308 non-null   object
#  24  owner__accept_rate                                        4255 non-null   float64
#  25  accepted_answer_id                                        7587 non-null   float64
#  26  locked_date                                               15 non-null     float64
#  27  protected_date                                            290 non-null    float64
#  28  migrated_from__other_site__styling__tag_background_color  83 non-null     object
#  29  migrated_from__other_site__styling__tag_foreground_color  83 non-null     object
#  30  migrated_from__other_site__styling__link_color            83 non-null     object
#  31  migrated_from__other_site__launch_date                    82 non-null     float64
#  32  migrated_from__other_site__open_beta_date                 82 non-null     float64
#  33  migrated_from__other_site__closed_beta_date               82 non-null     float64
#  34  migrated_from__other_site__site_state                     83 non-null     object
#  35  migrated_from__other_site__high_resolution_icon_url       83 non-null     object
#  36  migrated_from__other_site__favicon_url                    83 non-null     object
#  37  migrated_from__other_site__icon_url                       83 non-null     object
#  38  migrated_from__other_site__audience                       83 non-null     object
#  39  migrated_from__other_site__site_url                       83 non-null     object
#  40  migrated_from__other_site__api_site_parameter             83 non-null     object
#  41  migrated_from__other_site__logo_url                       83 non-null     object
#  42  migrated_from__other_site__name                           83 non-null     object
#  43  migrated_from__other_site__site_type                      83 non-null     object
#  44  migrated_from__on_date                                    83 non-null     float64
#  45  migrated_from__question_id                                83 non-null     float64
#  46  community_owned_date                                      13 non-null     float64
# dtypes: bool(1), float64(15), int64(7), object(24)
# memory usage: 6.9+ MB

# %%
# sort the data frame by creation_date ascending
asked_questions = answered_questions[::-1]

# %%
# get the questions that are passed to the GPT35 model 
asked_questions = asked_questions[:2000]

# %%
# read the log for the successful API response
gpt_answered_questions = []
with open('openai-gpt35-0125-log.txt', 'r') as f:
    for line in f:
        idx,status = line.strip().split("-")
        if status=="success":
            gpt_answered_questions.append(int(idx))

# gpt answered questions 
gpt_answered_questions = asked_questions.iloc[gpt_answered_questions]

# %%
print(preprocess_raw_html(asked_questions['body'].iloc[394]))
# Out:
# I was reading Wikipedia through materialism and physicalism article and was unable to find, whether modern scientists largely subscribe to physicalism in natural sciences. What is the scientific consensus on the metaphysical stances? To particularize: Does physicalism holds for mathematics and what is the mathematicians' consensus? Do natural scientists subscribe to physicalism in their fields? Do social scientists subscribe to physicalism in their fields?

# %% [markdown]
# ### Get the Azure AI GPT-35 (Model Version 0125) Response

# %%
gpt_generated_ans = []

with open("./gpt35_0125_philosophy_answers.jsonl", 'r') as f:
    for line in f:
        data = json.loads(line)
        if isinstance(data, str):
            data = json.loads(data)
        gpt_generated_ans.append(data)

# %%
len(gpt_generated_ans)
# Out:
# 1623

# %%
gpt_generated_ans[0].keys()
# Out:
# dict_keys(['id', 'choices', 'created', 'model', 'object', 'service_tier', 'system_fingerprint', 'usage'])

# %%
gpt_generated_ans[0]
# Out:
# {'id': 'chatcmpl-AAacygC0xlQIHzdZOcGCcnjiaUTLP',
#  'choices': [{'finish_reason': 'stop',
#    'index': 0,
#    'logprobs': None,
#    'message': {'content': 'The instrumentalist view of the universe is a philosophical perspective that holds that scientific theories should be seen as tools or instruments for making predictions and explaining observations, rather than as providing a true representation of reality. According to instrumentalism, scientific theories are judged solely by their predictive power and ability to account for empirical data, without making claims about the underlying reality that they describe.\n\nThere are several significant philosophical consequences that can arise from adopting an instrumentalist view of the universe:\n\n1. Epistemic humility: Instrumentalism can lead to an acknowledgment of the limitations of human knowledge and understanding. By viewing scientific theories as useful tools rather than definitive descriptions of reality, instrumentalism emphasizes the fallibility of scientific knowledge and the need to remain open to revising our theories in light of new evidence.\n\n2. Pragmatism: As you mentioned, the instrumentalist view is closely related to pragmatism, a philosophical tradition that emphasizes the practical consequences and utility of beliefs and theories. From an instrumentalist perspective, the value of a scientific theory lies in its usefulness for making predictions and guiding empirical inquiry, rather than in its correspondence to some ultimate truth.\n\n3. Anti-realism: Instrumentalism is often associated with anti-realism, the view that there is no objective reality independent of human perception and interpretation. Instrumentalists may eschew making metaphysical claims about the ultimate nature of reality and focus instead on the pragmatic value of scientific theories.\n\nWhile instrumentalism shares similarities with pragmatism and anti-realism, it also offers unique insights and perspectives on the nature of scientific knowledge and its relationship to reality. By emphasizing the instrumental role of scientific theories, instrumentalism encourages a focus on the practical consequences of scientific inquiry and the importance of empirical evidence in evaluating the success of scientific theories. Ultimately, the instrumentalist view can lead to a deeper appreciation of the provisional and pragmatic nature of scientific knowledge, while also raising important questions about the nature of reality and our relationship to it.',
#     'refusal': None,
#     'role': 'assistant',
#     'function_call': None,
#     'tool_calls': None}}],
#  'created': 1727087440,
#  'model': 'gpt-35-turbo',
#  'object': 'chat.completion',
#  'service_tier': None,
#  'system_fingerprint': 'fp_808245b034',
#  'usage': {'completion_tokens': 394, 'prompt_tokens': 71, 'total_tokens': 465}}

# %%
# arrange the order of questions to match the gpt-35 response
gpt_generated_ans = gpt_generated_ans[::-1]
gpt_generated_ans = gpt_generated_ans[:len(gpt_answered_questions)]
gpt_generated_ans = gpt_generated_ans[::-1]

# %%
# add the gpt answers as a new column 
df = gpt_answered_questions.assign(gpt35_0125_ans=gpt_generated_ans)

# %%
print(preprocess_raw_html(df["body"].iloc[10]),end="\n\n")
print(df["gpt35_0125_ans"].iloc[10]["choices"][0]["message"]["content"])
# Out:
# Possible Duplicate: What does “to cause” mean?  Take an example, It is reported that short-circuit caused fire in city bakery. In this case short-circuit and fire was in a causality, short-circuit is cause and fire is effect. But what is causality? Is cause a necessary or sufficient condition of effect? In this case it seems short-circuit is neither necessary nor sufficient condition of make a fire. But it seems also short-circuit is not entirely irrelevant to the fire. So my question is what is the proper definition of Causality?
#
# Causality is a fundamental concept in philosophy and science that refers to the relationship between cause and effect. It is the relationship between an event (the cause) and a second event (the effect), where the second event is understood to be a consequence of the first.
#
# In your specific example, the short-circuit is identified as the cause of the fire. The short-circuit is not a necessary condition for starting a fire in general, as fires can start from various causes such as sparks, heat sources, or chemicals. However, in this specific case, the short-circuit was indeed a contributing factor that led to the fire in the bakery.
#
# Causality is a complex concept that has been studied extensively in philosophy, science, and mathematics. It is often understood in terms of necessary and sufficient conditions, where a necessary condition is one that must be present for the effect to occur, and a sufficient condition is one that, if present, guarantees the effect will occur. In many cases, causality involves multiple causes and complex interactions between various factors.
#
# In summary, causality is the relationship between cause and effect, where one event influences the occurrence of another event. It is a fundamental concept that helps us understand the connections between events in the world around us.

# %% [markdown]
# ### Get the Philosophy Answers Based on the Asked Questions

# %%
questions_id = list(df["question_id"])

# %%
@dlt.resource(table_name="philosophy_answers", write_disposition="append")
def get_philosophy_answers(
    question_id,
    site='philosophy',
    page=1,
    pagesize=100,
    tag=None, 
):
    
    url = "https://api.stackexchange.com/2.3/questions" + f"/{question_id}" + "/answers" 
    params = {
        "site": site,
        "page": page,
        "pagesize": pagesize,
        "key": os.getenv("SE_API_KEY"),
        "filter": "withbody"
        # "tagged": tag,  
    }

    while True:
        response = requests.get(url,params=params)
        response.raise_for_status()
        yield response.json()
        
        if response.json()["has_more"]==False:
            break
        
        params["page"]+=1

# %%
pipeline = dlt.pipeline(
    pipeline_name="get_philosophy_answers_incremental",
    destination="duckdb",
    dataset_name="philosophy_answers",
)

# for i in range(len(questions_id)):
#     load_info = pipeline.run(get_philosophy_answers(questions_id[i]))
#     row_counts = pipeline.last_trace.last_normalize_info
#     print(row_counts)
#     print("------")
#     print(load_info)

# %%
conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

conn.sql(f"SET search_path = '{pipeline.dataset_name}'")
print('Loaded tables: ')
display(conn.sql("show tables"))
# Out:
# Loaded tables:
# ┌───────────────────────────┐
# │           name            │
# │          varchar          │
# ├───────────────────────────┤
# │ _dlt_loads                │
# │ _dlt_pipeline_state       │
# │ _dlt_version              │
# │ philosophy_answers        │
# │ philosophy_answers__items │
# └───────────────────────────┘

# %%
answers = conn.sql("SELECT * FROM philosophy_answers__items").df()
answers.head()
# Out:
#    owner__account_id  owner__reputation  owner__user_id owner__user_type  \
# 0            89797.0            16136.0           233.0       registered
# 1          1866755.0               51.0          2417.0     unregistered
# 2           947951.0              405.0          2429.0       registered
# 3           947951.0              405.0          2429.0       registered
# 4            23411.0              204.0          2571.0       registered
#
#    owner__accept_rate                               owner__profile_image  \
# 0                50.0  https://www.gravatar.com/avatar/3698349ad0b898...
# 1                 NaN  https://www.gravatar.com/avatar/b8ef13d2f91f83...
# 2                 NaN              https://i.sstatic.net/CtXUo.jpg?s=256
# 3                 NaN              https://i.sstatic.net/CtXUo.jpg?s=256
# 4                 NaN  https://www.gravatar.com/avatar/9a2f20624f0fcb...
#
#         owner__display_name  \
# 0                  Rex Kerr
# 1             Nigel Redding
# 2  Be Brave Be Like Ukraine
# 3  Be Brave Be Like Ukraine
# 4                     Tyler
#
#                                          owner__link  is_accepted  score  \
# 0  https://philosophy.stackexchange.com/users/233...         True      9
# 1  https://philosophy.stackexchange.com/users/241...        False      2
# 2  https://philosophy.stackexchange.com/users/242...         True      3
# 3  https://philosophy.stackexchange.com/users/242...        False      1
# 4  https://philosophy.stackexchange.com/users/257...         True      3
#
#    last_activity_date  creation_date  answer_id  question_id content_license  \
# 0          1350840403     1350840403       4008         4007    CC BY-SA 3.0
# 1          1352158249     1352158249       4141         4140    CC BY-SA 3.0
# 2          1352335268     1352335268       4151         4149    CC BY-SA 3.0
# 3          1351712605     1351712605       4107         4000    CC BY-SA 3.0
# 4          1350718288     1350718288       4001         4000    CC BY-SA 3.0
#
#                                                 body  _dlt_parent_id  \
# 0  <p>The <em>operational</em> consensus of physi...  15Ds9PswRVjGQA
# 1  <p>Aristotle discusses Ethics in his Nicomache...  S+voxsUTYselhg
# 2  <p><a href="http://www.freedominion.ca/phpBB2/...  jEuFb4GgOuRecQ
# 3  <pre><code>∀x ∈ Man : x ∈ People\n∃x ∈ Man : x...  u3aKRAX9UVRX5g
# 4  <pre><code>∀x (Man(x) → Person(x))\n∃x (Man(x)...  u3aKRAX9UVRX5g
#
#    _dlt_list_idx         _dlt_id  last_edit_date  community_owned_date
# 0              0  oJ/3cLXokMvZYg             NaN                   NaN
# 1              0  RD2skrHW1LQiZQ             NaN                   NaN
# 2              0  hfvU+3DlBY1E1A             NaN                   NaN
# 3              0  9tpjJW1GBIeJyA             NaN                   NaN
# 4              1  3FsSJBuRIpnxhw             NaN                   NaN

# %%
answers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2275 entries, 0 to 2274
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   owner__account_id     2147 non-null   float64
#  1   owner__reputation     2147 non-null   float64
#  2   owner__user_id        2147 non-null   float64
#  3   owner__user_type      2275 non-null   object
#  4   owner__accept_rate    667 non-null    float64
#  5   owner__profile_image  2147 non-null   object
#  6   owner__display_name   2275 non-null   object
#  7   owner__link           2147 non-null   object
#  8   is_accepted           2275 non-null   bool
#  9   score                 2275 non-null   int64
#  10  last_activity_date    2275 non-null   int64
#  11  creation_date         2275 non-null   int64
#  12  answer_id             2275 non-null   int64
#  13  question_id           2275 non-null   int64
#  14  content_license       2275 non-null   object
#  15  body                  2275 non-null   object
#  16  _dlt_parent_id        2275 non-null   object
#  17  _dlt_list_idx         2275 non-null   int64
#  18  _dlt_id               2275 non-null   object
#  19  last_edit_date        779 non-null    float64
#  20  community_owned_date  14 non-null     float64
# dtypes: bool(1), float64(6), int64(6), object(8)
# memory usage: 357.8+ KB
